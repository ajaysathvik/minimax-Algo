# %% [markdown]
# minimax algo with alpha-beta pruning

# %%
import random 
def GameBoard(board):
    for row in board:
        print("|".join(row))
    print('\n')    

def boardFull(board):
    if board is None:
        return False
    return not any(' ' in row for row in board) #if there is no space in any row, return true

def winningPlayer(board , player):
    win_states =(
        (0,1,2),(3,4,5),(6,7,8), #rows
        (0,3,6),(1,4,7),(2,5,8), #columns
        (0,4,8),(2,4,6) #diagonals
    )
    for state in win_states:
        if all(board[i] == player for i in state):
            return True 
    return False
    
def getScore(board):
    if winningPlayer(board, 'X'):
        return 1
    elif winningPlayer(board, 'O'):
        return -1
    else:
        return 0

def alphaBeta(board , depth , alpha , beta , is_maximizing):
    if winningPlayer(board, 'X'):
        return (1,None)
    elif winningPlayer(board, 'O'):
        return (-1,None)
    elif boardFull(board):
        return (0,None)
    
    if is_maximizing:
        best_score = -1000
        best_move = None
        for i in range(9):
            if board[i] == ' ':
                board[i] = 'X'
                score,_ = alphaBeta(board, depth - 1 , alpha , beta , False)
                board[i] = ' '
                if score > best_score:
                    best_score = score
                    best_move = i
                alpha = max(alpha , best_score)
                if beta <= alpha:
                    break
        if best_move is None:
            return (best_score,-1)
        else :
            return (best_score,best_move)
    else :
        best_score = 1000
        best_move = None
        for i in range(9):
            if board[i] == ' ':
                board[i] = 'O'
                score,_ = alphaBeta(board, depth - 1 , alpha , beta , True)
                board[i] = ' '
                if score < best_score:
                    best_score = score
                    best_move = i
                    beta = min(beta, best_score)
                    if beta <= alpha:
                        break
        if best_move is None:
            return (best_score,-1)
        else :
            return (best_score,best_move)

def computerMove(board):
    _,best_move = alphaBeta(board,9,-1000,1000,True)
    if best_move is not None:
        board[best_move] = 'X'
    return board

def playerMove(board):
    while True:
        move = int(input("Enter a number between 1 and 9: "))
        move -= 1
        if board[move] == ' ':
            board[move] = 'O'
            break
        else:
            print("That space is taken.")
    return board

def Play():
    board = [' '] * 9
    print("Welcome to Tic Tac Toe!") 
    print("You are O's and the computer is X's.")
    
    while True:
        GameBoard([board[i:i+3] for i in range(0,9,3)])
        board = playerMove(board)
        if winningPlayer(board,'O'):
            GameBoard([board[i:i+3] for i in range(0,9,3)])
            print("You win!")
            break
        elif boardFull(board):
            print("Tie!")
            break
        
        board = computerMove(board)
        
        if winningPlayer(board,'X'):
            GameBoard([board[i:i+3] for i in range(0,9,3)])
            print("You Lost!")
            break
        elif boardFull(board):
            print("Tie!")
            break

Play()
# Out:
# Welcome to Tic Tac Toe!
# You are O's and the computer is X's.
#  | |
#  | |
#  | |
#
#
# O| |
#  |X|
#  | |
#
#
# That space is taken.
# O|O|X
#  |X|
#  | |
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 119
#     116             print("Tie!")
#     117             break
# --> 119 Play()
#
# Cell In[1], line 100, in Play()
#      98 while True:
#      99     GameBoard([board[i:i+3] for i in range(0,9,3)])
# --> 100     board = playerMove(board)
#     101     if winningPlayer(board,'O'):
#     102         GameBoard([board[i:i+3] for i in range(0,9,3)])
#
# Cell In[1], line 84, in playerMove(board)
#      82 def playerMove(board):
#      83     while True:
# ---> 84         move = int(input("Enter a number between 1 and 9: "))
#      85         move -= 1
#      86         if board[move] == ' ':
#
# ValueError: invalid literal for int() with base 10: ''
